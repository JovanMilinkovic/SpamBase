# %% [markdown]
# <a href="https://colab.research.google.com/github/JovanMilinkovic/SpamBase/blob/main/SpamBase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('spambase_csv.csv')
df
# Out:
#       word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0               0.00               0.64           0.64           0.0
# 1               0.21               0.28           0.50           0.0
# 2               0.06               0.00           0.71           0.0
# 3               0.00               0.00           0.00           0.0
# 4               0.00               0.00           0.00           0.0
# ...              ...                ...            ...           ...
# 4596            0.31               0.00           0.62           0.0
# 4597            0.00               0.00           0.00           0.0
# 4598            0.30               0.00           0.30           0.0
# 4599            0.96               0.00           0.00           0.0
# 4600            0.00               0.00           0.65           0.0
#
#       word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# ...

# %%
df.head(25)
# Out:
#     word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0             0.00               0.64           0.64           0.0
# 1             0.21               0.28           0.50           0.0
# 2             0.06               0.00           0.71           0.0
# 3             0.00               0.00           0.00           0.0
# 4             0.00               0.00           0.00           0.0
# 5             0.00               0.00           0.00           0.0
# 6             0.00               0.00           0.00           0.0
# 7             0.00               0.00           0.00           0.0
# 8             0.15               0.00           0.46           0.0
# 9             0.06               0.12           0.77           0.0
# 10            0.00               0.00           0.00           0.0
# 11            0.00               0.00           0.25           0.0
# 12            0.00               0.69           0.34           0.0
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4601 entries, 0 to 4600
# Data columns (total 58 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   word_freq_make              4601 non-null   float64
#  1   word_freq_address           4601 non-null   float64
#  2   word_freq_all               4601 non-null   float64
#  3   word_freq_3d                4601 non-null   float64
#  4   word_freq_our               4601 non-null   float64
#  5   word_freq_over              4601 non-null   float64
#  6   word_freq_remove            4601 non-null   float64
#  7   word_freq_internet          4601 non-null   float64
#  8   word_freq_order             4601 non-null   float64
#  9   word_freq_mail              4601 non-null   float64
#  10  word_freq_receive           4601 non-null   float64
#  11  word_freq_will              4601 non-null   float64
#  12  word_freq_people            4601 non-null   float64
# ...

# %%
sns.histplot(data = df, x = 'capital_run_length_total', color = 'green')
# Out:
# <Axes: xlabel='capital_run_length_total', ylabel='Count'>

# %% [markdown]
# method 1 to count all values per column
#
# ---

# %%
counts_per_column = df.apply(pd.value_counts).fillna(0)
counts_per_column = np.sum(counts_per_column, axis=1)
counts_per_column
# Out:
# 0.000        205814.0
# 0.002            10.0
# 0.003             7.0
# 0.004             7.0
# 0.005             9.0
#                ...
# 9090.000          1.0
# 9163.000          1.0
# 9989.000          1.0
# 10062.000         1.0
# 15841.000         1.0
# Length: 4512, dtype: float64

# %% [markdown]
# method 2
#
# ---

# %%
words, counts = np.unique(df, return_counts = True)
words.shape[0]
# Out:
# 4512

# %%
counts
# Out:
# array([205814,     10,      7, ...,      1,      1,      1])

# %%
counts.sort()
counts=counts[4:]
counts
# Out:
# array([     1,      1,      1, ...,    597,   2619, 205814])

# %%
df2 = df.loc[:, df.columns.str.startswith('char_freq_')]
df2
# Out:
#       char_freq_%3B  char_freq_%28  char_freq_%5B  char_freq_%21  \
# 0             0.000          0.000            0.0          0.778
# 1             0.000          0.132            0.0          0.372
# 2             0.010          0.143            0.0          0.276
# 3             0.000          0.137            0.0          0.137
# 4             0.000          0.135            0.0          0.135
# ...             ...            ...            ...            ...
# 4596          0.000          0.232            0.0          0.000
# 4597          0.000          0.000            0.0          0.353
# 4598          0.102          0.718            0.0          0.000
# 4599          0.000          0.057            0.0          0.000
# 4600          0.000          0.000            0.0          0.125
#
#       char_freq_%24  char_freq_%23
# 0             0.000          0.000
# 1             0.180          0.048
# 2             0.184          0.010
# 3             0.000          0.000
# ...

# %%
df2.sum(axis=1)/6
# Out:
# 0       0.129667
# 1       0.122000
# 2       0.103833
# 3       0.045667
# 4       0.045000
#           ...
# 4596    0.038667
# 4597    0.058833
# 4598    0.136667
# 4599    0.009500
# 4600    0.020833
# Length: 4601, dtype: float64

# %%
df3 = df2.sum(axis=1)/6
df3
# Out:
# 0       0.129667
# 1       0.122000
# 2       0.103833
# 3       0.045667
# 4       0.045000
#           ...
# 4596    0.038667
# 4597    0.058833
# 4598    0.136667
# 4599    0.009500
# 4600    0.020833
# Length: 4601, dtype: float64

# %%
df = df.drop(df.loc[:, df.columns.str.startswith('char_freq_')], axis=1)
df
# Out:
#       word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0               0.00               0.64           0.64           0.0
# 1               0.21               0.28           0.50           0.0
# 2               0.06               0.00           0.71           0.0
# 3               0.00               0.00           0.00           0.0
# 4               0.00               0.00           0.00           0.0
# ...              ...                ...            ...           ...
# 4596            0.31               0.00           0.62           0.0
# 4597            0.00               0.00           0.00           0.0
# 4598            0.30               0.00           0.30           0.0
# 4599            0.96               0.00           0.00           0.0
# 4600            0.00               0.00           0.65           0.0
#
#       word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# ...

# %%
df['char_freq_MEAN'] = df3
df['char_freq_MEAN']
# Out:
# 0       0.129667
# 1       0.122000
# 2       0.103833
# 3       0.045667
# 4       0.045000
#           ...
# 4596    0.038667
# 4597    0.058833
# 4598    0.136667
# 4599    0.009500
# 4600    0.020833
# Name: char_freq_MEAN, Length: 4601, dtype: float64

# %% [markdown]
# Next and last is to train the model
#
# ---
